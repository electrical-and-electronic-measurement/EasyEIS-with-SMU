# %%
import matplotlib.pyplot as plt
import pandas

# %%
url = "https://raw.githubusercontent.com/emanbuc/keithley-2450-EIS/main/data/generated_current_sweep_samplebased.csv"
df_samplebased = pandas.read_csv(url, delimiter=";", header=None, names=["sample","value"])

url_timeased = "https://raw.githubusercontent.com/emanbuc/keithley-2450-EIS/main/data/generated_current_sweep_timebased.csv"
df_timebased = pandas.read_csv(url_timeased, delimiter=";", header=None, names=["sample","value"])

# %%
print(df_samplebased)
# Out:
#       sample     value
# 0          1  0.000125
# 1          2  0.000187
# 2          3  0.000249
# 3          4  0.000309
# 4          5  0.000368
# ...      ...       ...
# 1994    1995 -0.000249
# 1995    1996 -0.000187
# 1996    1997 -0.000125
# 1997    1998 -0.000063
# 1998    1999  0.000000
#
# [1999 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
plt.plot(df_samplebased.value,marker = '.')

# %%
plt.plot(df_timebased.value, marker = '.')

# %%
url_sweep_test_10K = "https://raw.githubusercontent.com/emanbuc/keithley-2450-EIS/main/data/sweep_test_R10K_load.csv"
df_sweep_test_10K = pandas.read_csv(url_sweep_test_10K, delimiter=";", header=None, names=["timestamp","current","voltage"])

# %%
import matplotlib.pyplot as plt
plt.plot(df_sweep_test_10K.current,marker = '.')

# %%
plt.plot(df_sweep_test_10K.voltage,marker = '.')

# %%
print(df_sweep_test_10K)
# Out:
#                           timestamp       current   voltage
# 0     02/07/2021 18:53:28.161005260  1.253410e-04  1.499570
# 1     02/07/2021 18:53:28.173474380  1.874520e-04  2.239640
# 2     02/07/2021 18:53:28.185904860  2.487170e-04  2.972470
# 3     02/07/2021 18:53:28.198331920  3.090590e-04  3.692990
# 4     02/07/2021 18:53:28.210758080  3.681550e-04  4.398110
# ...                             ...           ...       ...
# 1994  02/07/2021 18:54:10.897382020 -2.487020e-04 -2.969940
# 1995  02/07/2021 18:54:10.909798880 -1.873780e-04 -2.238570
# 1996  02/07/2021 18:54:10.922236400 -1.253170e-04 -1.497440
# 1997  02/07/2021 18:54:11.012413320 -6.279020e-05 -0.750214
# 1998  02/07/2021 18:54:11.251590480 -1.534770e-12  0.000114
#
# [1999 rows x 3 columns]
